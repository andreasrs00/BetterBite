# %%
import json
import time
import pandas as pd
from fatsecret import Fatsecret

# %%
consumer_key = '773e85024d944a90852f6c7b278fe3f4'
consumer_secret = '4978d27785764305962d95d887d2f8fa'
fs = Fatsecret(consumer_key, consumer_secret)

# %%
food_names = ["apple pie",
 "baby back ribs",
 "baklava",
 "beef carpaccio",
 "beef tartare",
 "beet salad",
 "beignets",
 "bibimbap",
 "bread pudding",
 "breakfast burrito",
 "caesar salad",
 "cannoli",
 "caprese salad",
 "carrot cake",
 "cheese plate",
 "cheesecake",
 "chicken quesadilla",
 "chicken wings",
 "chocolate cake",
 "chocolate mousse",
 "churros",
 "clam chowder",
 "club sandwich",
 "crab cakes",
 "creme brulee",
 "croque madame",
 "cup cakes",
 "deviled eggs",
 "donuts",
 "dumplings",
 "edamame",
 "eggs benedict",
 "escargots",
 "falafel",
 "filet mignon",
 "foie gras",
 "french fries",
 "french toast",
 "fried calamari",
 "fried rice",
 "frozen yogurt",
 "garlic bread",
 "grilled cheese sandwich",
 "grilled salmon",
 "guacamole",
 "gyoza",
 "hamburger",
 "hot and sour soup",
 "hot dog",
 "huevos rancheros",
 "hummus",
 "ice cream",
 "lasagna",
 "lobster bisque",
 "lobster roll sandwich",
 "macarons",
 "miso soup",
 "mussels",
 "nachos",
 "omelette",
 "onion rings",
 "oysters",
 "pad thai",
 "paella",
 "pancakes",
 "panna cotta",
 "peking duck",
 "pho",
 "pizza",
 "pork chop",
 "poutine",
 "prime rib",
 "pulled pork sandwich",
 "ramen",
 "red velvet cake",
 "risotto",
 "samosa",
 "sashimi",
 "seaweed salad",
 "spaghetti bolognese",
 "spaghetti carbonara",
 "spring rolls",
 "steak",
 "strawberry shortcake",
 "sushi",
 "tacos",
 "takoyaki",
 "tiramisu",
 "tuna tartare",
 "waffles"]

# %%
from itertools import islice

# %%
# Fungsi untuk membagi food_names menjadi beberapa bagian dengan ukuran tertentu
def chunked_iterable(iterable, size):
    it = iter(iterable)
    return iter(lambda: list(islice(it, size)), [])

# Membagi food_names menjadi bagian-bagian dengan masing-masing 25 item
chunked_food_names = chunked_iterable(food_names, 25)

# %%
# List untuk menyimpan informasi makanan dari semua bagian
all_food_information = []

# Memproses setiap bagian
for chunk in chunked_food_names:
    food_information = []
    for food_name in chunk:
        try:
            # Lakukan pencarian
            result = fs.foods_search(food_name)

            # Ambil hanya entri pertama jika ada hasil
            if result:
                food_information.append(result[0])  # Ambil entri pertama dari hasil

            # Delay untuk menghindari rate limit
            time.sleep(5)

        except json.JSONDecodeError as e:
            print(f"Error decoding JSON for {food_name}: {e}")
        except Exception as e:
            print(f"An unexpected error occurred for {food_name}: {e}")

    # Tambahkan hasil dari bagian ini ke all_food_information
    all_food_information.extend(food_information)

# Cetak hasil satu per satu di baris baru
for info in all_food_information:
    print(json.dumps(info, indent=2))
# Out:
# {
#   "food_description": "Per 100g - Calories: 265kcal | Fat: 12.50g | Carbs: 37.10g | Protein: 2.40g",
#   "food_id": "39016",
#   "food_name": "Apple Pie",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/apple-pie"
# }
# {
#   "brand_name": "Signature Cafe",
#   "food_description": "Per 4 ribs - Calories: 210kcal | Fat: 15.00g | Carbs: 4.00g | Protein: 17.00g",
#   "food_id": "3066288",
#   "food_name": "Baby Back Ribs",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/signature-cafe/baby-back-ribs"
# }
# {
#   "brand_name": "Mediterranean",
#   "food_description": "Per 2 pieces - Calories: 160kcal | Fat: 9.00g | Carbs: 17.00g | Protein: 2.00g",
#   "food_id": "64613374",
#   "food_name": "Baklava",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/mediterranean/baklava"
# }
# {
#   "food_description": "Per 100g - Calories: 119kcal | Fat: 2.62g | Carbs: 0.00g | Protein: 22.31g",
#   "food_id": "7406497",
#   "food_name": "Carpaccio",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/carpaccio-beef"
# }
# {
#   "food_description": "Per 100g - Calories: 210kcal | Fat: 14.56g | Carbs: 0.63g | Protein: 17.78g",
#   "food_id": "2211",
#   "food_name": "Steak Tartare (Raw Ground Beef and Egg)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/steak-tartare-(raw-ground-beef-and-egg)"
# }
# {
#   "brand_name": "Urban Plates",
#   "food_description": "Per 1 serving - Calories: 170kcal | Fat: 11.00g | Carbs: 14.00g | Protein: 6.00g",
#   "food_id": "30097653",
#   "food_name": "Beet Salad with Goat Cheese",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/urban-plates/beet-salad-with-goat-cheese"
# }
# {
#   "brand_name": "Cafe Du Monde",
#   "food_description": "Per 1 beignets - Calories: 110kcal | Fat: 7.00g | Carbs: 12.00g | Protein: 2.00g",
#   "food_id": "1180655",
#   "food_name": "Beignets",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/cafe-du-monde/beignets"
# }
# {
#   "brand_name": "Bibigo",
#   "food_description": "Per 1 bowl  - Calories: 340kcal | Fat: 6.00g | Carbs: 56.00g | Protein: 13.00g",
#   "food_id": "19397154",
#   "food_name": "Korean Style Bibimbap Beef",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/bibigo/korean-style-bibimbap-beef"
# }
# {
#   "food_description": "Per 822g - Calories: 1258kcal | Fat: 38.96g | Carbs: 191.18g | Protein: 43.32g",
#   "food_id": "1188",
#   "food_name": "Bread Pudding",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/pudding-bread"
# }
# {
#   "food_description": "Per 181g - Calories: 366kcal | Fat: 22.25g | Carbs: 21.52g | Protein: 19.40g",
#   "food_id": "603728",
#   "food_name": "Breakfast Burrito",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/burrito-breakfast"
# }
# {
#   "food_description": "Per 630g - Calories: 1072kcal | Fat: 89.33g | Carbs: 41.10g | Protein: 31.71g",
#   "food_id": "5898",
#   "food_name": "Caesar Salad with Romaine",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/caesar-salad-(with-romaine)"
# }
# {
#   "food_description": "Per 2408g - Calories: 6120kcal | Fat: 265.92g | Carbs: 694.59g | Protein: 209.60g",
#   "food_id": "597678",
#   "food_name": "Cannoli",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/pastry-cannoli"
# }
# {
#   "brand_name": "Bertucci's",
#   "food_description": "Per 1 serving - Calories: 280kcal | Fat: 20.00g | Carbs: 10.00g | Protein: 19.00g",
#   "food_id": "1208802",
#   "food_name": "Tomato Mozzarella Caprese Salad",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/bertuccis/tomato-mozzarella-caprese-salad"
# }
# {
#   "food_description": "Per 1704g - Calories: 6952kcal | Fat: 355.78g | Carbs: 902.40g | Protein: 65.77g",
#   "food_id": "3803",
#   "food_name": "Carrot Cake with Icing",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/cake-carrot-with-icing"
# }
# {
#   "brand_name": "Fresh & Easy",
#   "food_description": "Per 1 unit - Calories: 430kcal | Fat: 19.00g | Carbs: 49.00g | Protein: 17.00g",
#   "food_id": "189152",
#   "food_name": "Fruit & Cheese Plate",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/fresh-and-easy/fruit-and-cheese-plate"
# }
# {
#   "food_description": "Per 100g - Calories: 321kcal | Fat: 22.50g | Carbs: 25.50g | Protein: 5.50g",
#   "food_id": "38873",
#   "food_name": "Cheesecake",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/cheesecake"
# }
# {
#   "food_description": "Per 184g - Calories: 564kcal | Fat: 31.59g | Carbs: 37.12g | Protein: 31.61g",
#   "food_id": "4874",
#   "food_name": "Quesadilla with Poultry and Cheese",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/quesadilla-with-poultry-and-cheese"
# }
# {
#   "food_description": "Per 101g - Calories: 290kcal | Fat: 19.46g | Carbs: 0.00g | Protein: 26.86g",
#   "food_id": "1714",
#   "food_name": "Chicken Wing (Skin Eaten)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/chicken-wing-skin-eaten"
# }
# {
#   "food_description": "Per 100g - Calories: 367kcal | Fat: 16.40g | Carbs: 54.60g | Protein: 4.10g",
#   "food_id": "38840",
#   "food_name": "Chocolate Cake (with Chocolate Frosting)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/chocolate-cake-(with-chocolate-frosting)"
# }
# {
#   "food_description": "Per 870g - Calories: 1817kcal | Fat: 131.39g | Carbs: 140.00g | Protein: 36.17g",
#   "food_id": "1227",
#   "food_name": "Chocolate Mousse",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/mousse-chocolate"
# }
# {
#   "food_description": "Per 498g - Calories: 2225kcal | Fat: 140.75g | Carbs: 228.64g | Protein: 13.89g",
#   "food_id": "4223",
#   "food_name": "Churros",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/churros"
# }
# {
#   "food_description": "Per 100g - Calories: 67kcal | Fat: 2.39g | Carbs: 7.79g | Protein: 3.62g",
#   "food_id": "3043",
#   "food_name": "Clam Chowder",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/clam-chowder"
# }
# {
#   "food_description": "Per 211g - Calories: 471kcal | Fat: 21.01g | Carbs: 42.06g | Protein: 26.62g",
#   "food_id": "2784",
#   "food_name": "Bacon, Chicken and Tomato Club Sandwich with Lettuce and Spread",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/bacon-chicken-and-tomato-club-sandwich-with-lettuce-and-spread"
# }
# {
#   "food_description": "Per 552g - Calories: 927kcal | Fat: 44.03g | Carbs: 3.70g | Protein: 122.67g",
#   "food_id": "2386",
#   "food_name": "Crab Cake",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/crab-cake"
# }
# {
#   "food_description": "Per 411g - Calories: 1383kcal | Fat: 110.12g | Carbs: 90.06g | Protein: 13.90g",
#   "food_id": "4322117",
#   "food_name": "Creme Brulee",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/creme-brulee"
# }
# {
#   "brand_name": "La Madeleine",
#   "food_description": "Per 1 serving - Calories: 890kcal | Fat: 40.00g | Carbs: 76.00g | Protein: 51.00g",
#   "food_id": "74270989",
#   "food_name": "Croque Madame",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/la-madeleine/croque-madame"
# }
# {
#   "food_description": "Per 100g - Calories: 305kcal | Fat: 3.70g | Carbs: 67.20g | Protein: 4.30g",
#   "food_id": "39134",
#   "food_name": "Cupcakes with Frosting (Low Fat)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/cupcakes-with-frosting-(low-fat)"
# }
# {
#   "food_description": "Per 55g - Calories: 110kcal | Fat: 8.89g | Carbs: 0.74g | Protein: 6.34g",
#   "food_id": "3111",
#   "food_name": "Deviled Egg",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/egg-deviled"
# }
# {
#   "food_description": "Per 100g - Calories: 426kcal | Fat: 22.90g | Carbs: 50.80g | Protein: 5.20g",
#   "food_id": "38969",
#   "food_name": "Sugared or Glazed Doughnuts",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/sugared-or-glazed-doughnuts"
# }
# {
#   "food_description": "Per 819g - Calories: 918kcal | Fat: 21.63g | Carbs: 78.32g | Protein: 94.63g",
#   "food_id": "4926",
#   "food_name": "Steamed Dumpling (Filled with Meat Poultry or Seafood)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/dumpling-steamed-filled-with-meat-poultry-or-seafood"
# }
# {
#   "food_description": "Per 100g - Calories: 81kcal | Fat: 4.45g | Carbs: 6.53g | Protein: 8.47g",
#   "food_id": "36575",
#   "food_name": "Soybeans (Mature Seeds, Steamed, Cooked)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/soybeans-(mature-seeds-steamed-cooked)"
# }
# {
#   "brand_name": "Perkins Restaurant",
#   "food_description": "Per 1 serving - Calories: 660kcal | Fat: 31.00g | Carbs: 61.00g | Protein: 34.00g",
#   "food_id": "853454",
#   "food_name": "Classic Eggs Benedict",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/perkins-restaurant/classic-eggs-benedict"
# }
# {
#   "brand_name": "Escal",
#   "food_description": "Per 6 escargots - Calories: 190kcal | Fat: 17.00g | Carbs: 3.00g | Protein: 4.00g",
#   "food_id": "3753447",
#   "food_name": "Escargots with Garlic Butter",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/escal/escargots-with-garlic-butter"
# }
# {
#   "food_description": "Per 100g - Calories: 333kcal | Fat: 17.80g | Carbs: 31.84g | Protein: 13.31g",
#   "food_id": "38346",
#   "food_name": "Falafel",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/falafel"
# }
# {
#   "brand_name": "Schwan's",
#   "food_description": "Per 6 oz - Calories: 250kcal | Fat: 11.00g | Carbs: 0.00g | Protein: 35.00g",
#   "food_id": "2233929",
#   "food_name": "Filet Mignon",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/schwans/filet-mignon"
# }
# {
#   "brand_name": "Vons",
#   "food_description": "Per 2 oz - Calories: 250kcal | Fat: 24.00g | Carbs: 2.00g | Protein: 6.00g",
#   "food_id": "6018289",
#   "food_name": "Duck Foie Gras",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/vons/duck-foie-gras"
# }
# {
#   "food_description": "Per 100g - Calories: 274kcal | Fat: 14.08g | Carbs: 35.71g | Protein: 3.49g",
#   "food_id": "5762",
#   "food_name": "Potato French Fries",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/white-potato-french-fries"
# }
# {
#   "food_description": "Per 342g - Calories: 835kcal | Fat: 32.28g | Carbs: 105.43g | Protein: 29.41g",
#   "food_id": "4384",
#   "food_name": "Plain French Toast",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/french-toast-plain"
# }
# {
#   "food_description": "Per 1071g - Calories: 1336kcal | Fat: 23.21g | Carbs: 106.07g | Protein: 162.05g",
#   "food_id": "584997",
#   "food_name": "Fried Calamari",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/calamari-fried"
# }
# {
#   "food_description": "Per 1023g - Calories: 1719kcal | Fat: 63.73g | Carbs: 215.44g | Protein: 64.45g",
#   "food_id": "5099",
#   "food_name": "Fried Rice",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/rice-fried"
# }
# {
#   "food_description": "Per 100g - Calories: 107kcal | Fat: 1.47g | Carbs: 19.62g | Protein: 4.70g",
#   "food_id": "865",
#   "food_name": "Frozen Yogurt",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/yogurt-frozen-ns-as-to-type-of-milk"
# }
# {
#   "food_description": "Per 116g - Calories: 383kcal | Fat: 14.83g | Carbs: 52.92g | Protein: 8.99g",
#   "food_id": "3469",
#   "food_name": "Garlic Bread",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/bread-garlic"
# }
# {
#   "food_description": "Per 89g - Calories: 312kcal | Fat: 16.96g | Carbs: 29.95g | Protein: 9.85g",
#   "food_id": "1336",
#   "food_name": "Grilled Cheese Sandwich",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/cheese-sandwich-grilled"
# }
# {
#   "food_description": "Per 100g - Calories: 139kcal | Fat: 4.30g | Carbs: 0.00g | Protein: 23.45g",
#   "food_id": "2058",
#   "food_name": "Cooked Salmon",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/salmon-cooked"
# }
# {
#   "food_description": "Per 412g - Calories: 647kcal | Fat: 58.95g | Carbs: 35.05g | Protein: 8.07g",
#   "food_id": "5571",
#   "food_name": "Guacamole",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/guacamole"
# }
# {
#   "brand_name": "Hungry Planet",
#   "food_description": "Per 4 gyoza - Calories: 120kcal | Fat: 2.50g | Carbs: 17.00g | Protein: 7.00g",
#   "food_id": "58704864",
#   "food_name": "Gyoza",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/hungry-planet/gyoza"
# }
# {
#   "food_description": "Per 100g - Calories: 254kcal | Fat: 20.00g | Carbs: 0.00g | Protein: 17.17g",
#   "food_id": "40406",
#   "food_name": "Ground Beef (80% Lean / 20% Fat)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/ground-beef-(80%25-lean---20%25-fat)"
# }
# {
#   "food_description": "Per 1135g - Calories: 761kcal | Fat: 36.78g | Carbs: 23.05g | Protein: 70.27g",
#   "food_id": "3027",
#   "food_name": "Hot and Sour Soup",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/hot-and-sour-soup"
# }
# {
#   "food_description": "Per 100g - Calories: 294kcal | Fat: 17.62g | Carbs: 22.24g | Protein: 10.66g",
#   "food_id": "2839",
#   "food_name": "Frankfurter or Hot Dog on Bun",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/frankfurter-or-hot-dog-plain-on-bun"
# }
# {
#   "food_description": "Per 254g - Calories: 302kcal | Fat: 16.92g | Carbs: 21.67g | Protein: 17.50g",
#   "food_id": "3136",
#   "food_name": "Huevos Rancheros",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/huevos-rancheros"
# }
# {
#   "food_description": "Per 100g - Calories: 177kcal | Fat: 8.59g | Carbs: 20.12g | Protein: 4.86g",
#   "food_id": "38345",
#   "food_name": "Hummus",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/hummus"
# }
# {
#   "food_description": "Per 100g - Calories: 201kcal | Fat: 10.71g | Carbs: 24.38g | Protein: 3.52g",
#   "food_id": "1107",
#   "food_name": "Ice Cream",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/ice-cream"
# }
# {
#   "food_description": "Per 3294g - Calories: 5369kcal | Fat: 197.96g | Carbs: 566.55g | Protein: 328.07g",
#   "food_id": "4989",
#   "food_name": "Lasagna with Meat",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/lasagna-with-meat"
# }
# {
#   "food_description": "Per 1429g - Calories: 1429kcal | Fat: 73.61g | Carbs: 73.03g | Protein: 115.34g",
#   "food_id": "3055",
#   "food_name": "Lobster Bisque",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/lobster-bisque"
# }
# {
#   "brand_name": "D'angelo",
#   "food_description": "Per 1 serving - Calories: 410kcal | Fat: 30.00g | Carbs: 31.00g | Protein: 22.00g",
#   "food_id": "75157748",
#   "food_name": "Lobster Roll Sandwich Box (Catering)",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/dangelo/lobster-roll-sandwich-box-(catering)"
# }
# {
#   "brand_name": "Private Selection",
#   "food_description": "Per 2 cookies - Calories: 100kcal | Fat: 5.00g | Carbs: 12.00g | Protein: 2.00g",
#   "food_id": "25545924",
#   "food_name": "Macarons",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/private-selection/macarons"
# }
# {
#   "food_description": "Per 1389g - Calories: 486kcal | Fat: 19.44g | Carbs: 45.00g | Protein: 34.86g",
#   "food_id": "3301",
#   "food_name": "Miso Soup",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/soybean-soup-miso-broth"
# }
# {
#   "food_description": "Per 485g - Calories: 727kcal | Fat: 40.00g | Carbs: 21.38g | Protein: 66.81g",
#   "food_id": "2163",
#   "food_name": "Cooked Mussels",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/mussels-cooked"
# }
# {
#   "food_description": "Per 100g - Calories: 306kcal | Fat: 16.77g | Carbs: 32.15g | Protein: 8.05g",
#   "food_id": "39915",
#   "food_name": "Nachos with Cheese",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/nachos-with-cheese"
# }
# {
#   "brand_name": "Village Inn",
#   "food_description": "Per 1 serving - Calories: 300kcal | Fat: 27.00g | Carbs: 2.00g | Protein: 20.00g",
#   "food_id": "6847018",
#   "food_name": "2 Egg Cheese Omelette",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/village-inn/2-egg-cheese-omelette"
# }
# {
#   "food_description": "Per 100g - Calories: 332kcal | Fat: 18.69g | Carbs: 37.74g | Protein: 4.46g",
#   "food_id": "39967",
#   "food_name": "Onion Rings (Breaded and Fried)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/onion-rings-(breaded-and-fried)"
# }
# {
#   "food_description": "Per 100g - Calories: 68kcal | Fat: 2.46g | Carbs: 3.91g | Protein: 7.05g",
#   "food_id": "2165",
#   "food_name": "Oysters",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/oysters-raw"
# }
# {
#   "food_description": "Per 1134g - Calories: 1930kcal | Fat: 72.31g | Carbs: 255.04g | Protein: 65.66g",
#   "food_id": "5873757",
#   "food_name": "Pad Thai",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/pad-thai"
# }
# {
#   "food_description": "Per 2220g - Calories: 3507kcal | Fat: 120.76g | Carbs: 370.28g | Protein: 211.34g",
#   "food_id": "2568",
#   "food_name": "Paella",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/paella"
# }
# {
#   "food_description": "Per 100g - Calories: 227kcal | Fat: 9.70g | Carbs: 28.30g | Protein: 6.40g",
#   "food_id": "39009",
#   "food_name": "Plain Pancakes",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/plain-pancakes"
# }
# {
#   "food_description": "Per 60g - Calories: 134kcal | Fat: 7.40g | Carbs: 14.03g | Protein: 0.65g",
#   "food_id": "4303280",
#   "food_name": "Panna Cotta",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/panna-cotta"
# }
# {
#   "food_description": "Per 100g - Calories: 337kcal | Fat: 28.35g | Carbs: 0.00g | Protein: 18.99g",
#   "food_id": "34525",
#   "food_name": "Duck Meat and Skin (Roasted, Cooked)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/duck-meat-and-skin-(roasted-cooked)"
# }
# {
#   "brand_name": "Annie Chun's",
#   "food_description": "Per 1 bowl - Calories: 300kcal | Fat: 1.00g | Carbs: 64.00g | Protein: 10.00g",
#   "food_id": "32163270",
#   "food_name": "Vietnamese Style Pho Soup Bowl",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/annie-chuns/vietnamese-style-pho-soup-bowl"
# }
# {
#   "food_description": "Per 100g - Calories: 276kcal | Fat: 11.74g | Carbs: 30.33g | Protein: 12.33g",
#   "food_id": "4881",
#   "food_name": "Cheese Pizza",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/pizza-cheese"
# }
# {
#   "food_description": "Per 100g - Calories: 144kcal | Fat: 5.89g | Carbs: 0.00g | Protein: 21.35g",
#   "food_id": "36081",
#   "food_name": "Pork Chops (Top Loin, Boneless)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/pork-chops-(top-loin-boneless)"
# }
# {
#   "brand_name": "New York Fries",
#   "food_description": "Per 1 serving - Calories: 710kcal | Fat: 38.00g | Carbs: 75.00g | Protein: 19.00g",
#   "food_id": "265853",
#   "food_name": "Poutine (Small)",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/new-york-fries/poutine-(small)"
# }
# {
#   "food_description": "Per 100g - Calories: 267kcal | Fat: 17.39g | Carbs: 0.00g | Protein: 26.02g",
#   "food_id": "475002",
#   "food_name": "Prime Rib",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/beef-standing-rib-roast"
# }
# {
#   "food_description": "Per 166g - Calories: 284kcal | Fat: 8.19g | Carbs: 30.26g | Protein: 20.71g",
#   "food_id": "2803",
#   "food_name": "Pork Barbecue Sandwich or Sloppy Joe on Bun",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/pork-barbecue-sandwich-or-sloppy-joe-on-bun"
# }
# {
#   "brand_name": "Maruchan",
#   "food_description": "Per 1/2 block noodles with seasoning - Calories: 190kcal | Fat: 7.00g | Carbs: 27.00g | Protein: 4.00g",
#   "food_id": "145482",
#   "food_name": "Ramen Noodle Soup - Chicken Flavor",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/maruchan/ramen-noodle-soup---chicken-flavor"
# }
# {
#   "food_description": "Per 1204g - Calories: 4417kcal | Fat: 206.85g | Carbs: 563.58g | Protein: 82.05g",
#   "food_id": "6098856",
#   "food_name": "Red Velvet Cake",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/cake-red-velvet"
# }
# {
#   "brand_name": "Lundberg",
#   "food_description": "Per 1/2 cup cooked - Calories: 140kcal | Fat: 1.50g | Carbs: 27.00g | Protein: 5.00g",
#   "food_id": "70594",
#   "food_name": "Creamy Parmesan Risotto",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/lundberg/creamy-parmesan-risotto"
# }
# {
#   "food_description": "Per 753g - Calories: 2319kcal | Fat: 134.50g | Carbs: 242.56g | Protein: 35.17g",
#   "food_id": "4956",
#   "food_name": "Pastry filled with Potatoes and Peas (Fried)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/pastry-filled-with-potatoes-and-peas-fried"
# }
# {
#   "food_description": "Per 100g - Calories: 146kcal | Fat: 5.93g | Carbs: 0.00g | Protein: 21.62g",
#   "food_id": "437027",
#   "food_name": "Salmon Sashimi",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/sashimi-salmon"
# }
# {
#   "brand_name": "Sushiya",
#   "food_description": "Per 1 cup - Calories: 130kcal | Fat: 4.50g | Carbs: 23.00g | Protein: 3.00g",
#   "food_id": "5491247",
#   "food_name": "Seaweed Salad",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/sushiya/seaweed-salad"
# }
# {
#   "food_description": "Per 1005g - Calories: 1470kcal | Fat: 51.38g | Carbs: 182.79g | Protein: 71.58g",
#   "food_id": "4524271",
#   "food_name": "Spaghetti Bolognese",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/spaghetti-with-bolognese-sauce"
# }
# {
#   "food_description": "Per 1786g - Calories: 3410kcal | Fat: 94.81g | Carbs: 459.24g | Protein: 143.74g",
#   "food_id": "5071",
#   "food_name": "Pasta with Carbonara Sauce",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/pasta-with-carbonara-sauce"
# }
# {
#   "food_description": "Per 1179g - Calories: 1153kcal | Fat: 52.29g | Carbs: 137.09g | Protein: 36.59g",
#   "food_id": "499712",
#   "food_name": "Vegetable Spring Roll",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/spring-roll-meatless"
# }
# {
#   "food_description": "Per 100g - Calories: 201kcal | Fat: 12.71g | Carbs: 0.00g | Protein: 20.30g",
#   "food_id": "37657",
#   "food_name": "Beef Top Sirloin (Trimmed to 1/8\" Fat)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/usda/beef-top-sirloin-(trimmed-to-1-8-fat)"
# }
# {
#   "food_description": "Per 158g - Calories: 283kcal | Fat: 6.79g | Carbs: 53.29g | Protein: 5.23g",
#   "food_id": "3929",
#   "food_name": "Shortcake Sponge with Whipped Cream and Fruit",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/cake-shortcake-sponge-type-with-whipped-cream-and-fruit"
# }
# {
#   "food_description": "Per 1345g - Calories: 1924kcal | Fat: 5.65g | Carbs: 402.26g | Protein: 57.85g",
#   "food_id": "5104",
#   "food_name": "Sushi",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/sushi"
# }
# {
#   "food_description": "Per 78g - Calories: 221kcal | Fat: 12.65g | Carbs: 16.20g | Protein: 10.88g",
#   "food_id": "4823",
#   "food_name": "Taco or Tostada with Beef, Cheese and Lettuce",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/taco-or-tostada-with-beef-cheese-and-lettuce"
# }
# {
#   "food_description": "Per 851g - Calories: 1489kcal | Fat: 64.32g | Carbs: 151.25g | Protein: 71.89g",
#   "food_id": "5796962",
#   "food_name": "Takoyaki",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/takoyaki"
# }
# {
#   "food_description": "Per 1393g - Calories: 3944kcal | Fat: 253.62g | Carbs: 340.15g | Protein: 66.47g",
#   "food_id": "1234",
#   "food_name": "Tiramisu",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/tiramisu"
# }
# {
#   "brand_name": "Seasons 52",
#   "food_description": "Per 1 serving - Calories: 350kcal | Fat: 14.00g | Carbs: 25.00g | Protein: 32.00g",
#   "food_id": "73950918",
#   "food_name": "Ahi Tuna Tartare",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/seasons-52/ahi-tuna-tartare"
# }
# {
#   "brand_name": "Eggo",
#   "food_description": "Per 2 waffles - Calories: 180kcal | Fat: 7.00g | Carbs: 28.00g | Protein: 6.00g",
#   "food_id": "59737",
#   "food_name": "Homestyle Waffles (2)",
#   "food_type": "Brand",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/eggo/homestyle-waffles-(2)"
# }

# %%
all_food_id = []
for food_data in all_food_information:
    try:
        food_id = food_data['food_id']
        all_food_id.append(food_id)
    except (KeyError, TypeError):
        print("food_id not found or invalid data format in all_food_information")

# %%
all_food_id
# Out:
# ['39016',
#  '3066288',
#  '64613374',
#  '7406497',
#  '2211',
#  '30097653',
#  '1180655',
#  '19397154',
#  '1188',
#  '603728',
#  '5898',
#  '597678',
#  '1208802',
#  '3803',
#  '189152',
#  '38873',
#  '4874',
#  '1714',
#  '38840',
#  '1227',
#  '4223',
#  '3043',
#  '2784',
#  '2386',
#  '4322117',
#  '74270989',
#  '39134',
#  '3111',
#  '38969',
#  '4926',
#  '36575',
#  '853454',
#  '3753447',
#  '38346',
#  '2233929',
#  '6018289',
#  '5762',
#  '4384',
#  '584997',
#  '5099',
#  '865',
#  '3469',
#  '1336',
#  '2058',
#  '5571',
#  '58704864',
#  '40406',
#  '3027',
#  '2839',
#  '3136',
#  '38345',
#  '1107',
#  '4989',
#  '3055',
#  '75157748',
#  '25545924',
#  '3301',
#  '2163',
#  '39915',
#  '6847018',
#  '39967',
#  '2165',
#  '5873757',
#  '2568',
#  '39009',
#  '4303280',
#  '34525',
#  '32163270',
#  '4881',
#  '36081',
#  '265853',
#  '475002',
#  '2803',
#  '145482',
#  '6098856',
#  '70594',
#  '4956',
#  '437027',
#  '5491247',
#  '4524271',
#  '5071',
#  '499712',
#  '37657',
#  '3929',
#  '5104',
#  '4823',
#  '5796962',
#  '1234',
#  '73950918',
#  '59737']

# %%
# Fungsi untuk membagi iterable menjadi bagian-bagian dengan ukuran tertentu
def chunked_iterable(iterable, size):
    it = iter(iterable)
    return iter(lambda: list(islice(it, size)), [])

# Membagi all_food_id menjadi bagian-bagian dengan masing-masing 25 item
chunked_all_food_id = chunked_iterable(all_food_id, 25)

# %%
all_food_data = []

# Loop untuk mengambil data makanan satu per satu
for food_id in all_food_id:
    try:
        result = fs.food_get_v2(food_id)
        if result:
            all_food_data.append(result)
        time.sleep(10)  # Delay 2 detik untuk menghindari rate limit
    except Exception as e:
        print(f"Error for food_id {food_id}: {e}")

# Cetak jumlah data yang berhasil diambil
print(f"Total food data fetched: {len(all_food_data)}")
# Out:
# Total food data fetched: 90

# %%
print(json.dumps(all_food_data[29], indent=2))
# Out:
# {
#   "food_id": "4926",
#   "food_name": "Steamed Dumpling (Filled with Meat Poultry or Seafood)",
#   "food_type": "Generic",
#   "food_url": "https://www.fatsecret.com/calories-nutrition/generic/dumpling-steamed-filled-with-meat-poultry-or-seafood",
#   "servings": {
#     "serving": [
#       {
#         "calcium": "7",
#         "calories": "41",
#         "carbohydrate": "3.54",
#         "cholesterol": "18",
#         "fat": "0.98",
#         "fiber": "0.2",
#         "iron": "0.51",
#         "measurement_description": "dumpling",
#         "metric_serving_amount": "37.000",
#         "metric_serving_unit": "g",
#         "monounsaturated_fat": "0.359",
#         "number_of_units": "1.000",
#         "polyunsaturated_fat": "0.201",
#         "potassium": "70",
#         "protein": "4.27",
#         "saturated_fat": "0.274",
#         "serving_description": "1 dumpling",
#         "serving_id": "17542",
#         "serving_url": "https://www.fatsecret.com/calories-nutrition/generic/dumpling-steamed-filled-with-meat-poultry-or-seafood?portionid=17542&portionamount=1.000",
#         "sodium": "161",
#         "sugar": "0.21",
#         "vitamin_a": "5",
#         "vitamin_c": "0.5"
#       },
#       {
#         "calcium": "19",
#         "calories": "112",
#         "carbohydrate": "9.56",
#         "cholesterol": "48",
#         "fat": "2.64",
#         "fiber": "0.5",
#         "iron": "1.38",
#         "measurement_description": "g",
#         "metric_serving_amount": "100.000",
#         "metric_serving_unit": "g",
#         "monounsaturated_fat": "0.971",
#         "number_of_units": "100.000",
#         "polyunsaturated_fat": "0.542",
#         "potassium": "188",
#         "protein": "11.55",
#         "saturated_fat": "0.740",
#         "serving_description": "100 g",
#         "serving_id": "53606",
#         "serving_url": "https://www.fatsecret.com/calories-nutrition/generic/dumpling-steamed-filled-with-meat-poultry-or-seafood?portionid=53606&portionamount=100.000",
#         "sodium": "435",
#         "sugar": "0.57",
#         "vitamin_a": "13",
#         "vitamin_c": "1.3"
#       },
#       {
#         "calcium": "7",
#         "calories": "41",
#         "carbohydrate": "3.54",
#         "cholesterol": "18",
#         "fat": "0.98",
#         "fiber": "0.2",
#         "iron": "0.51",
#         "measurement_description": "serving (37g)",
#         "metric_serving_amount": "37.000",
#         "metric_serving_unit": "g",
#         "monounsaturated_fat": "0.359",
#         "number_of_units": "1.000",
#         "polyunsaturated_fat": "0.201",
#         "potassium": "70",
#         "protein": "4.27",
#         "saturated_fat": "0.274",
#         "serving_description": "1 serving (37 g)",
#         "serving_id": "16886",
#         "serving_url": "https://www.fatsecret.com/calories-nutrition/generic/dumpling-steamed-filled-with-meat-poultry-or-seafood?portionid=16886&portionamount=1.000",
#         "sodium": "161",
#         "sugar": "0.21",
#         "vitamin_a": "5",
#         "vitamin_c": "0.5"
#       }
#     ]
#   }
# }

# %%
import csv

# Nama file CSV
csv_file = "data_with_servings.csv"

# Kolom utama
main_columns = ['food_name', 'food_id', 'food_type', 'food_url']

# Kolom tambahan dari servings
serving_columns = ['calcium', 'calories', 'carbohydrate', 'cholesterol', 'fat', 'fiber', 'iron', 
                   'potassium', 'protein', 'saturated_fat', 'monounsaturated_fat', 'polyunsaturated_fat', 'serving_description', 'sodium', 'sugar', 'vitamin_a', 'vitamin_c']

# Gabungkan semua kolom
columns = main_columns + serving_columns

# Membuka file CSV untuk menulis data
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=columns)
    writer.writeheader()

    for food in all_food_data:
        base_row = {col: food.get(col, '') for col in main_columns}
        servings = food.get('servings', {}).get('serving', [])

        # Ubah ke list jika hanya satu serving dalam bentuk dict
        if isinstance(servings, dict):
            servings = [servings]

        for serving in servings:
            row = base_row.copy()
            row.update({col: serving.get(col, '') for col in serving_columns})
            writer.writerow(row)

print(f"{csv_file} berhasil dibuat dengan semua food dan servings-nya 🎉")
# Out:
# data_with_servings.csv berhasil dibuat dengan semua food dan servings-nya 🎉

# %%
# Nama file JSON
json_file = "data_with_servings.json"

# Membuka file JSON untuk menulis data
with open(json_file, mode='w', encoding='utf-8') as file:
    json.dump(all_food_data, file, ensure_ascii=False, indent=2)

print(f"{json_file} berhasil dibuat dengan semua food dan servings-nya 🎉")
# Out:
# data_with_servings.json berhasil dibuat dengan semua food dan servings-nya 🎉
